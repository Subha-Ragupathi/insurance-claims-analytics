# %% [markdown]
# # Master Pipeline — End-to-End Orchestration
# Runs all pipeline stages in sequence:
# 1. Bronze Ingestion (with schema validation)
# 2. Silver Transformation (with cleaning and dedup)
# 3. Gold Aggregation (with partitioned outputs)
# 4. Data Quality Checks (across all tables)
# 5. Gold SQL Analytics

# %%
# MAGIC %run ./01_bronze_ingestion

# %%
# MAGIC %run ./02_silver_transformation

# %%
# MAGIC %run ./03_gold_aggregation

# %%
# MAGIC %run ./04_data_quality_checks

# %%
# MAGIC %run ./05_gold_sql_analytics
