# %%
# Databricks notebook source
# MAGIC %run ./01_bronze_ingestion.py

# COMMAND ----------

# MAGIC %run ./02_silver_transformation.py

# COMMAND ----------

# MAGIC %run ./03_gold_aggregation.py

# COMMAND ----------

# MAGIC %run ./04_data_quality_checks.py
